# %% [markdown]
# # Assignment 4 – Python Set
#
# **Name:** Sumit panorekar
# **Roll No.:** 20997
# **Subject:** Principles of Programming Language

# %% [markdown]
# ### Question: Union, Intersection and Difference of Sets

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# Finding union of two sets
print('Union:', set1.union(set2))

# Finding intersection of two sets
print('Intersection:', set1.intersection(set2))

# Finding difference of two sets
print('Difference:', set1.difference(set2))
